# %% [markdown]
# # **Soft Demodulation Using Neural Networks**
# *Author - Minu Jung*
#
# Following code is an implementation and experimentation of *Machine LLRning - Learning to Softly Demodulate* by *Ori Shental* and *Jacob Hoydis (Bell Labs)*
#
# The primary purpose of this project was to test and compare the results of demodulating signals using traditional demodulation methods using exact/approximate log-likelihood ratios, and the proposed neural net demodulator. The secondary purpose was to write the program such that the simulated communication network and the *LLRnet* can be easily customized and tested with a relatively simple interface.
#
# Following is the model of the simulated Transmitter:
# ![alt text](https://drive.google.com/uc?id=1MM7jQ56447Hp3Fxgjf0FYU8D8rCYCL3n)
# Following is the model of the simulated Receiver and Decoder:
# ![alt text](https://drive.google.com/uc?id=1VJVxRIujo_HB_vDL_6sXrbf4_zIkVnQV)
#
# The transmitter and receiver is save in a single object ```Transmitter_Receiver```, and the following are the commands to simulate the network. You must specify the number of bits to send, the modulation scheme, the signal to noise ratio to simulate and method of log-likeihood calculation.
#
# All components in the transmitter and receiver were simulated, with the exception of the Parallel to Serial Converter, at cost of efficiency. For example, performance will be faster if constellation symbols were randomly generated with AWGN noise, but this approach doesn't reflect other structures in transmitter/receiver systems.
#
# ```
# communication_network = Transmitter_Receiver(num_bits_send, modulation)
# communication_network.send_n_receive(snr)
# communication_network.decode(llr_calc = 'approx')
# ```
# *Please note that my understanding of deep learning networks is introductory at best, which limited the scope of this project to making an easily testable, customizable system that could allow anyone to experiment with different number of layers, activation functions, loss functions, optimizers, SNRs, modulation schemes, etc and quantitatively compare bit error rates to traditional decoding system's bit error rates*

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import special as sp
from constants import k48, k96, k192, k288
from constants import w48, w96, w192, w288

def qfunc(arg):
    return 0.5-0.5*sp.erf(arg/1.414)

# %% [markdown]
# # Gray Coded Binary Grid to Constellation:
#
# The modulation scheme and corresponding constellation is saved in the object ```Modulation_Map``` which is a dictionary that maps the binary stream (bit_stream) of k binary bits into exact constellation points, with the gray coded modulation schemes saved in a global 2D list. For example, if ```modulation == '16QAM'``` will use this matrix to map to constellation points using the function ```create_bin_to_coordinate_matrix```:
# ```
# QAM_16_b = [['0000', '0100', '1100', '1000'],
#            ['0001', '0101', '1101', '1001'],
#            ['0011', '0111', '1111', '1011'],
#            ['0010', '0110', '1110', '1010']]
# ```

# %%
QAM_64 = [[4, 12, 28, 20, 52, 60, 44, 36],
          [5, 13, 29, 21, 53, 61, 45, 37],
          [7, 15, 31, 23, 55, 63, 47, 39],
          [6, 14, 30, 22, 54, 62, 46, 38],
          [2, 10, 26, 18, 50, 58, 42, 34],
          [3, 11, 27, 19, 51, 59, 43, 35],
          [1, 9, 25, 17, 49, 57, 41, 33],
          [0, 8, 24, 16, 48, 56, 40, 32]]

QAM_16 = [[2, 6, 14, 10],
          [3, 7, 15, 11],
          [1, 5, 13,  9],
          [0, 4, 12,  8]]

QAM_4 = [[1, 3],
         [0, 2]]

BPSK_2 = [[0, 1]]

PSK_8 = [[0, 1, 5, 4, 6, 7, 3, 2]]
#
# QAM_64_b = [['000100', '001100', '011100', '010100', '110100', '111100', '101100', '100100'],
#             ['000101', '001101', '011101', '010101', '110101', '111101', '101101', '100101'],
#             ['000111', '001111', '011111', '010111', '110111', '111111', '101111', '100111'],
#             ['000110', '001110', '011110', '010110', '110110', '111110', '101110', '100110'],
#             ['000010', '001010', '011010', '010010', '110010', '111010', '101010', '100010'],
#             ['000011', '001011', '011011', '010011', '110011', '111011', '101011', '100011'],
#             ['000001', '001001', '011001', '010001', '110001', '111001', '101001', '100001'],
#             ['000000', '001000', '011000', '010000', '110000', '111000', '101000', '100000']]
#
# QAM_16_b = [['0000', '0100', '1100', '1000'],
#             ['0001', '0101', '1101', '1001'],
#             ['0011', '0111', '1111', '1011'],
#             ['0010', '0110', '1110', '1010']]
#
# QAM_4_b = [['01', '11'],
#            ['00', '10']]
#
# BPSK_2_b = [['0', '1']]

QAM_64_b = [['000100', '001100', '011100', '010100', '110100', '111100', '101100', '100100'],
            ['000101', '001101', '011101', '010101', '110101', '111101', '101101', '100101'],
            ['000111', '001111', '011111', '010111', '110111', '111111', '101111', '100111'],
            ['000110', '001110', '011110', '010110', '110110', '111110', '101110', '100110'],
            ['000010', '001010', '011010', '010010', '110010', '111010', '101010', '100010'],
            ['000011', '001011', '011011', '010011', '110011', '111011', '101011', '100011'],
            ['000001', '001001', '011001', '010001', '110001', '111001', '101001', '100001'],
            ['000000', '001000', '011000', '010000', '110000', '111000', '101000', '100000']]

QAM_16_b = [['0010', '0110', '1110', '1010'],
            ['0011', '0111', '1111', '1011'],
            ['0001', '0101', '1101', '1001'],
            ['0000', '0100', '1100', '1000']]

QAM_4_b = [['01', '11'],
           ['00', '10']]

BPSK_2_b = [['0', '1']]


PSK_8_b = [['000', '001', '101', '100', '110', '111', '011', '010']]

class Modulation_Map():
  def __init__(self, modulation):
    self.modulation = modulation
    if modulation == '4QAM':
      self.number_matrix, self.binary_matrix = QAM_4, QAM_4_b
    elif modulation == '16QAM':
      self.number_matrix, self.binary_matrix = QAM_16, QAM_16_b
    elif modulation == '64QAM':
      self.number_matrix, self.binary_matrix = QAM_64, QAM_64_b
    elif modulation == 'BPSK':
      self.number_matrix, self.binary_matrix = BPSK_2, BPSK_2_b
    elif modulation == '8PSK':
      self.number_matrix, self.binary_matrix = PSK_8, PSK_8_b
    self.create_num_to_bin_dictionary()
    self.create_bin_to_coordinate_dictionary()

  def create_num_to_bin_dictionary(self):
    number_matrix = self.number_matrix
    binary_matrix = self.binary_matrix
    n, d = len(number_matrix), len(number_matrix[0])
    num_to_bin = {}
    for i in range(n):
      for j in range(d):
        key = number_matrix[i][j]
        value = binary_matrix[i][j]
        num_to_bin[key] = value
    self.num_to_bin = num_to_bin
  
  def create_bin_to_coordinate_dictionary(self):
    number_matrix = self.number_matrix
    binary_matrix = self.binary_matrix
    n, d = len(number_matrix), len(number_matrix[0])
    bin_to_coordinate = {}
    for i in range(n):
      for j in range(d):
        key = binary_matrix[i][j]
        if self.modulation == '4QAM':
          value = -1 + 2*j, -1 + 2*i
        elif self.modulation == '16QAM':
          value = -3 + 2*i, -3 + 2*j
        elif self.modulation == '64QAM':
          value = -7 + 2*i, -7 + 2*j
        elif self.modulation == 'BPSK':
          value = -1 + 2*j, i 
        else: #8PSK
          value = math.sin(j*math.pi/4), math.cos(j*math.pi/4)
        bin_to_coordinate[key] = value
        self.bin_to_coordinate = bin_to_coordinate

# %% [markdown]
# # Transmitter and Receiver:
# The transmitter consists of four main parts.
#
# 1. ```generate_bits()``` and ```serial_to_parallel()``` have rather trivial implementations. The serial-to-parallel converter divides the 1-Dimension serial bits into (k, k/n) 2-Dimensional array.
#
# 2. ```y = bit_stream_to_constellation()``` uses  ```Modulation_Map``` to map k-bits into the specific constellation coordinates based on the modulation scheme.
#
# 3.  ```snr_to_N0()``` converts the input snr into $N_0$, the noise power spectral density ratio, which twice the variance of the AWGN. The equation used to convert snr to $N_0$ was $N_0 = \frac{e_{avg}}{k\times SNR}$, where the average energy is calculated by finding the average of each symbol energy in the constellation.
# 4. ```r = add_noise(y, N_0/2)``` simulates AWGN with $\sigma^2 =\frac{N_0}{2}$. The final received signal is ```r```.

# %% [markdown]
# # Decoder, and LLR Calculation
#
# The decoder calculates the bit least log-likelihood ratios given the received signal. There are two methods to calculate the LLR: The exact calculation and the approximate calculation. This can be specified, eg. ```decode(llr_calc = 'approx')```
#
# # LLR Calculation
#
# The exact LLR calculation is made by using the following equation (from Machine LLrning):
# $$l_{i} \triangleq \log \left(\frac{\operatorname{Pr}\left(c_{i}=0 | \hat{\mathrm{r}}\right)}{\operatorname{Pr}\left(c_{i}=1 | \hat{\mathrm{r}}\right)}\right), \quad i=1, \ldots, k$$
#
#
# $$l_{i}=\log \frac{\sum_{\mathbf{r} \in \mathcal{C}_{i}^{0}} \exp \left(-\frac{\|\hat{\mathbf{r}}-\mathbf{r}\|_{1}^{2}}{\sigma^{2}}\right)}{\sum_{\mathbf{r} \in \mathcal{C}_{i}^{1}} \exp \left(-\frac{\|\hat{\mathbf{r}}-\mathbf{r}\|_{1}^{2}}{\sigma^{2}}\right)}, \quad i=1, \ldots, k$$
#
# Where the set of signals where the i-th bit $c_i$ is 0 or 1 is found using the Modulation_Map.
#
# The approximate LLR calculation is made by using the following equation, which estimates the log-likeihood ratios based on the shortest distance between the symbols and the received symbols.
# $$l_{i} \approx \frac{1}{\sigma^{2}}\left(\min _{\mathbf{r} \in \mathcal{C}_{i}^{1}}\|\hat{\mathbf{r}}-\mathbf{r}\|_{2}^{2}-\min _{\mathbf{r} \in \mathcal{C}_{i}^{0}}\|\hat{\mathbf{r}}-\mathbf{r}\|_{2}^{2}\right), \quad i=1, \ldots, M$$
#
# Note that at high SNR, the exact calculation becomes numerically unstable as either the denominator or numerator reaches 0, leading to undefined behavior.
#
# #Decoder
#
# The decoder classifies the $i$th bit as $0$ if $l_i \geq 0$ and $1$ if $l_i < 0$
#
# Following is the code for  ```Transmitter_Receiver```, which contains both the transmitter, receiver and decoder

# %%
class Transmitter_Receiver():
  def __init__(self, num_bits_send, modulation):
    self.num_bits_send = num_bits_send
    self.modulation = modulation
    self.modulation_map = Modulation_Map(modulation)
    self.Scrambling = True
    self.Interleaving = True
    if modulation == '4QAM':
      self.M = 4; self.k = 2; self.NCBPS = 96; self.binary_matrix = QAM_4_b
    elif modulation == '16QAM':
      self.M = 16; self.k = 4; self.NCBPS = 192; self.binary_matrix = QAM_16_b
    elif modulation == '64QAM':
      self.M = 64; self.k = 6; self.NCBPS = 288; self.binary_matrix = QAM_64_b
    elif modulation == 'BPSK':
      self.M = 2; self.k = 1; self.NCBPS = 48;self.binary_matrix = BPSK_2_b
    else: #8PSK
      self.M = 8; self.k = 3; self.binary_matrix = PSK_8_b
    
  def send_n_receive(self, snr, verbose = False):
    self.snr = snr
    N_0 = self.snr_to_N0()
    self.N_0 = N_0
    if verbose:
      print('Sending %d bits with snr = %fdB' %(self.num_bits_send, snr))
    self.generate_bits()
    self.serial_to_parallel()
    y = self.bit_stream_to_constellation()
    r = self.add_noise(y, N_0/2)
    self.r = r
    if verbose:
      plt.scatter(r[0,:], r[1, :])
      print('Finished Sending %d bits with snr = %fdB\n' %(self.num_bits_send, snr))

  def decode(self, llr_calc = 'approx', verbose=False):
    if verbose:
      print('Decoding %d bits...' %(self.num_bits_send))
    r = self.r
    # print(r.shape)
    # print(r)
    n, d = np.shape(r)
    llr = np.zeros((self.k, d))
    decoded = np.zeros((self.k, d))
    for i in range(d):
      if llr_calc == 'approx':
        single_message_llr = self.r_to_llr_approx(r[:, i])
      else: #EXACT
        single_message_llr = self.r_to_llr(r[:, i])
      # print(single_message_llr)
      llr[:, i] = np.flip(single_message_llr)
      decoded[:, i] = np.flip((1-(single_message_llr/np.abs(single_message_llr)))/2)

    bit_error = np.sum(np.abs(decoded-self.bit_stream))
    bit_error_rate = bit_error/self.num_bits_send
    self.bit_error = bit_error
    self.bit_error_rate = bit_error_rate
    self.llr = llr
    self.decoded = decoded
    if verbose:
      print('Finished decoding %d bits...' %(self.num_bits_send))
      print('Number of Bit Errors: %d' %(bit_error))
      print('Bit Error Rate: %f\n' %(bit_error_rate))

  def r_to_llr(self, r):
    '''
    Returns: k array of llrs
    '''
    # print(r.shape)
    # print(r)
    k = self.k
    modulation_map = self.modulation_map
    llr = np.zeros(k)
    for i in range(k):
      zero_sum, one_sum = 0, 0
      for key in modulation_map.bin_to_coordinate.keys():
        r_ = modulation_map.bin_to_coordinate[key]
        r_ = np.array([r_[0], r_[1]])
        exponent = np.linalg.norm(r-r_)
        exponent = -1*exponent/(self.N_0/2)
        total = math.exp(exponent)
        if key[k-i-1] == '0':
          zero_sum += total
        else:
          one_sum += total
      llr[i] = math.log2(zero_sum) - math.log2(one_sum)
      llr[i] = 10**-5 if llr[i] == 0 else llr[i]
    return llr    

  def r_to_llr_approx(self, r):
    '''
    Returns: k array of llrs
    '''
    k = self.k
    modulation_map = self.modulation_map
    llr = np.zeros(k)
    for i in range(k):
      zero_sum, one_sum = [], []
      for key in modulation_map.bin_to_coordinate.keys():
        r_ = modulation_map.bin_to_coordinate[key]


        r_ = np.array([r_[0], r_[1]])
        # print(f"r_:  {r_.shape}")
        exponent = np.linalg.norm(r-r_)
        total = exponent
        if key[k-i-1] == '0':
          zero_sum.append(total)
        else:
          one_sum.append(total)
      llr[i] = (min(one_sum) - min(zero_sum)) #/(self.N_0/2)
      llr[i] = 10**-5 if llr[i] == 0 else llr[i]
    return llr 
  
  def snr_to_N0(self):
    '''
    Returns: float N0
    '''
    k, M, snr = self.k, self.M, 10**(self.snr/10)
    sum = 0
    for value in self.modulation_map.bin_to_coordinate.values():
      sum += value[0]**2+value[1]**2
    e_avg = sum/M
    return e_avg/(k*snr)
  def bi2de(self, binary):
    x = 0
    for n in range(0, len(binary)):
        x = (binary[n]*(2**n)) + x
    return x
  def de2bi(self, n, N):
    bseed= bin(n).replace("0b", "")
    fix = N-len(bseed)
    pad = np.zeros(fix)
    pad = pad.tolist()
    y = []
    for i in range(len(pad)):
        y = [int(pad[i])] + y
    for i in range(len(bseed)):
        y = [int(bseed[i])] + y
    return y

  def scrambler(self, seed = [1,0,1,1,1,0,1]):
        # initialize scrambler
    # scramble
    bits = self.bit_stream.ravel()
    bit_count = len(bits)
    scrambled_bits = np.zeros(bit_count)
    N=7
    seed = self.bi2de(seed)
    bseed = self.de2bi(seed,N)
    x1 = bseed[0]
    x2 = bseed[1]
    x3 = bseed[2]
    x4 = bseed[3]
    x5 = bseed[4]
    x6 = bseed[5]
    x7 = bseed[6]

    for n in range(bit_count):
        x1t = x1
        x2t = x2
        x3t = x3
        x4t = x4
        x5t = x5
        x6t = x6
        x7t = x7
        var = int(x4t)^int(x7t)
        scrambled_bits[n] =int(var)^int(bits[n])
        x1 = var
        x2 = x1t
        x3 = x2t
        x4 = x3t
        x5 = x4t
        x6 = x5t
        x7 = x6t

    self.bit_stream = scrambled_bits.reshape((-1,1))


  def generate_bits(self ):
    '''
    Sets bit_stream to: num_bits_send, 1 array of bits
    '''
    # make num_bits_send a multiple of Nbpsc
    # e.g Nbpsc =  4 for 16-QAM
    Nbits = self.num_bits_send  + self.k - (self.num_bits_send % self.k)
    self.num_bits_send = Nbits
    bit_stream = np.around(np.random.rand(Nbits,1))
    self.bit_stream = bit_stream

    # Scramble bits so there are not many repeated ones or zeros.

    if self.Scrambling:
      self.scrambler()


  def serial_to_parallel(self):
    '''
    Sets bit_stream to: k, n/k array of bits
    '''
    k = self.k
    c = self.bit_stream
    n, d = np.shape(c)
    
    if n%k == 0:
      copy = np.transpose(c.reshape((int(n/k), k)))
      self.bit_stream = copy
    else:
      copy = np.append(c, np.zeros((k-n%k,1)))
      n_, = np.shape(copy)
      self.bit_stream = np.transpose(copy.reshape((int(n_/k), k)))  
  
  def bit_stream_to_constellation(self):
    '''
    Returns: 2,d array of 2-D coordinate points
    '''
    modulation = self.modulation
    modulation_map = self.modulation_map
    bit_stream = self.bit_stream
    n,d = np.shape(bit_stream)
    constellation = np.zeros((2,d))

    for j in range(d):
      stream = bit_stream[:, j]
      key = ''
      for bit in stream:
        key += str(int(bit))
      x1, y1 = modulation_map.bin_to_coordinate[key]
      constellation[0, j], constellation[1,j] = x1, y1
    return constellation

  def add_noise(self, y, var):
    n, d = np.shape(y)
    return y + math.sqrt(var)*np.random.randn(n, d)

# %% [markdown]
# #Example Constellation Plots
# Following are the constellation plots for all modulations with 20dB SNR

# %%
modulation_list = ['BPSK', '4QAM', '16QAM', '64QAM']
snr = 25
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]
for modulation, ax in zip(modulation_list, axes):
  comm_sys = Transmitter_Receiver(10000, modulation)
  comm_sys.send_n_receive(snr) 
  ax.scatter(comm_sys.r[0,:], comm_sys.r[1,:])
  ax.set_title(modulation)
  ax.set_xlabel('Re'); ax.set_ylabel('Im')
  ax.set_aspect('equal')

# %% [markdown]
# #Theoretical Bit Error Rate Calculation and Comparison
#
# #MAP detection Probability of Error:
#
# When using the optimal detector, i.e. MAP detector, we seek to detect the signal that is
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS_SVG-full" type="text/javascript"></script>
#
# $$\underset{m}{\operatorname{arg max}}{P}(s_m|r) = \underset{m}{\operatorname{arg max}}\frac{P(r|s_m)P(s_m)}{P(r)}$$
#
# In equiprobable signals (as is the case here, MAP detector reduces to ML detector)
# $$\underset{m}{\operatorname{arg max}}{P}(s_m|r) = \underset{m}{\operatorname{arg max}}P(r|s_m)$$
#
# Assuming that the received signal $P(r|s_m)$ is a multivariate normal distribution with diagonal covariance matrix (independent)
# $$f(r|s_m)=(\pi N_0)^{-\frac{d}{2}}\prod_{i=0}^{d-1}e^{-\frac{2}{N_0}(r_i-s_{mi})^2}$$
# $$r, s_m \in \mathbb{C}^d$$
# Taking the natural log of the likelihood and disregarding values that do not effect argmax, we can arrive at the optimal detector value
#
# $$\underset{m}{\operatorname{arg max}}{P}(s_m|r) = \underset{m}{\operatorname{arg min}} ||r-s_m||^2$$
#
# This imposes a decision region for each $s_m$ such that the closest constellation point within that region is $s_m$. In the case of binary signals, the threshold is 0, which makes the probability of error easy to calculate:
#
# $$P(e) = P(e|s_1)P(s_1)+P(e|s_0)P(s_0)$$
# $$P(e) = \int_{-\infty}^{0}f(r|s_1)dr\cdot P(s_1) + \int_{0}^{\infty}f(r|s_2)dr\cdot P(s_2)$$
# $$f(r|s_m)= \frac{1}{\sqrt{\pi N_0}}e^{-\frac{(r-s_m)^2}{N_0}}$$
#
# Therefore the probability of error can be reduced to the Q function,
# $$P(e) = 0.5(1-Q((\frac{\sqrt{\epsilon_b}}{\sqrt{\frac{N_0}{2}}}))) + 0.5Q(-(\frac{\sqrt{\epsilon_b}}{\sqrt{\frac{N_0}{2}}})))$$
# For equiprobable signal. Note that $1-Q(-x) = Q(x)$
# $$\therefore P(e) = 0.5\times 2Q(\sqrt{\frac{2\epsilon_b}{N_0}}) = Q(\sqrt{\frac{2\epsilon_b}{N_0}})$$
# This can be reduced to $P(e) = Q\left(\frac{d_{min}}{\sqrt{2N_0}}\right)$, as $d_{min} = 2\sqrt{e_b}$
#
# However, calculating probability of error quickly becomes complicated for other modulation schemes that do not have simple regions of detection.
#
# Therefore, instead of the exact probability, we aim to find a bound on the probability of error, using Union Bound.
#
# With equiprobable signals, the probability of error can be reduced to:
# $$P(e) = P(e|s_m) = \sum_{i=1}^{M}P(s_i \text{ detected} | s_m \text{ sent}) \text{ for } i \neq m$$
# From the section above, $P(s_i \text{ detected} | s_m \text{ sent})$ means that $||r-s_i||^2 < ||r-s_m||^2 $, meaning it can be modeled ass a binary equiprobable signaling system, for which the probability of error was found above:
# $$Q\left(\frac{d_{m:i}}{\sqrt{2N_0}}\right)$$
# $$\therefore P(e) = P(e|s_m) = \sum_{i=1}^{M}Q\left(\frac{d_{m:i}}{\sqrt{2N_0}}\right) \text{, }i\neq m $$
#
# Since the Q function is monotonically decreasing, $Q\left(\frac{d_{m:i}}{\sqrt{2N_0}}\right) \leq Q\left(\frac{d_{min}}{\sqrt{2N_0}}\right) $
# $$\therefore \sum_{i=1}^{M}Q\left(\frac{d_{m:i}}{\sqrt{2N_0}}\right) \leq (M-1)Q\left(\frac{d_{min}}{\sqrt{2N_0}}\right) $$
#
# Therefore, the approximation for probability of symbol error is:
#
# $$P(e) \approx (M-1)Q\left(\frac{d_{min}}{\sqrt{2N_0}}\right) $$
#
# The proof for bit error rates for all modulation schemes is not shown here, but the following table was used:
# $$\begin{array}{lll}
# \text { Modulation } & P_{s}\left(\gamma_{s}\right) & P_{b}\left(\gamma_{b}\right) \\
# \hline \text { BPSK } & & P_{b}=Q(\sqrt{2\gamma_b}) \\
# \text { QPSK } & P_{s} \approx 2 Q(\sqrt{\gamma_{s}}) & P_{b} \approx Q(\sqrt{2 \gamma_{b}}) \\
# \text { 8PSK } & P_{s} \approx 2 Q\left(\sqrt{2 \gamma_{s}} \sin \left(\frac{\pi}{8}\right)\right) & P_{b} \approx \frac{2}{\log_{2} 8} Q(\sqrt{2 \gamma_{b} \log _{2} M} \sin(\frac{\pi}{8}) \\
# \text { M-QAM } & P_{s} \approx 4 Q(\sqrt{\frac{3\gamma_s}{M-1}}) & P_{b} \approx \frac{4}{\log _{2} M} Q(\sqrt{\frac{3\gamma_b log_{2}M}{M-1}})
# \end{array}$$
#
# where $\gamma_b = \frac{\epsilon_b}{N_0}$, the SNR per bit.

# %%
def theoretical_bit_error_rate(modulation, SNR_dB):
  snr = 10**(SNR_dB/10)
  if modulation == 'BPSK':
    bit_error = qfunc((2*snr)**0.5)
  elif modulation == '8PSK':
    M = 8
    bit_error = 2/((math.log2(M)))*qfunc(math.sin(math.pi/M)*(2*snr*math.log2(M))**0.5)
  elif modulation == '4QAM' or modulation == '16QAM' or modulation == '64QAM':
    M = 4 if modulation == '4QAM' else 16 if modulation == '16QAM' else 64
    bit_error = 4/((math.log2(M)))*qfunc((3*snr*math.log2(M)/(M-1))**0.5)
  else:
    print('Must choose valid modulation')
    return 0
  return bit_error

# %% [markdown]
# Following graphs checks whether the theoretical BER coincides with the optimal detector BER

# %%
SNR_Range = [-10,31] # 0,31
spacing = 1
snr_list = np.linspace(SNR_Range[0],SNR_Range[1],int(np.abs(SNR_Range[0]-SNR_Range[1])*1/spacing)+1)
modulation_list = [ 'BPSK', '4QAM', '16QAM', '64QAM']
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]
for modulation, ax in zip(modulation_list, axes):
  conventional_error = []
  th_error = []
  for snr in snr_list:
    # print(snr)
    comm_sys = Transmitter_Receiver(3000, modulation)
    comm_sys.send_n_receive(snr)
    comm_sys.decode()
    conventional_error.append(comm_sys.bit_error_rate)
    th_error.append((theoretical_bit_error_rate(modulation, snr)))
  ax.semilogy(snr_list, conventional_error, linewidth = 4, label = 'Simulation BER')
  ax.semilogy(snr_list, th_error, linewidth = 2, label = 'Theoretical BER')
  ax.set_xlabel('SNR per bit (dB)'); ax.set_ylabel('BER')
  ax.legend()
  ax.set_title(modulation + ' BER')

# %% [markdown]
# # LLR_net

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers
from keras import optimizers
from keras import initializers
from keras.callbacks import TensorBoard
import pickle
from time import time
from datetime import datetime

# %%
NAME = "LLRnet-{}".format(datetime.now().strftime("%Y%m%d_%H%M%S%U"))
tensorboard =  TensorBoard(log_dir='logs/{}'.format(NAME))

# %% [markdown]
# LLR_net is a customizable sequential feed forward neural network decoder, and parameters for the model can be defined in the declaration. For example:
# ```
# modulation, training_size, test_size = '4QAM', 100, 1000
# train_snr, test_snr = 10, 15
# epoch_size, activation, optimizer, loss = 100, 'relu', 'adam', 'mse'
# neuron_size, layer_num = 8, 2
# llr_net = LLR_net(modulation, training_size, test_size, train_snr = train_snr, test_snr = test_snr,
#                   epoch_size = epoch_size, activation = activation, optimizer = optimizer,
#                   loss = loss, neuron_size = neuron_size, layer_num = layer_num)
# ```
# The above declaration sets up a 4QAM decoder trained on 100 samples at SNR = 10dB with 100 epochs, tested on 1000 samples at SNR = 15dB. There will be 2 layers with 8 neurons, with activation function 'relu', optimizer 'adam' with loss fuction 'mse'.
#
# **Note that in the original paper, the primary goal was to decode signals with lower complexity, which was only possible for ONE hidden layer with less than 8 neurons. Adding additional layers adds to complexity, and will be slower than traditional minimum distance calculations**

# %%
class LLR_net():
  def __init__(self, modulation, training_size, test_size, train_snr=10, test_snr=10, epoch_size=50,
               activation = 'tanh', optimizer = 'adam', loss = 'mse', neuron_size = 16, layer_num = 1):
    """


    :param modulation: 'BPSK' | '4QAM' | '16QAM' | '64QAM'
    :param training_size: 50000
    :param test_size: 10000
    :param train_snr: 10
    :param test_snr: 5
    :param epoch_size: 30
    :param activation: 'relu' | 'tanh'
    :param optimizer: 'adam' | 'sgd'
    :param loss: 'binary_crossentropy' | 'mse'
    :param neuron_size: K  =  8 |16 | 32 based on Modulation order
    :param layer_num: 1 one layer is sufficient
    """
    self.activation = activation
    self.modulation = modulation
    self.neuron_size = 16 if self.modulation == '64QAM' else 8
    self.loss, self.optimizer = loss, optimizer
    self.train_snr, self.test_snr = train_snr, test_snr
    self.training_size, self.test_size = training_size, test_size
    self.model_history = {}
    '''
    Model Definition: Sequential
    Model Paramters: The parameters can be specified in the declaration. Optimization of Parameters
                      are given in next sections
    Note:
    Last Layer is defined in the training system to account for different 'k' values
    '''
    model = Sequential()
    model.add(Dense(self.neuron_size, input_dim=2, activation = activation))
    for i in range(layer_num):
        model.add(Dropout(0.2))
        model.add(Dense(self.neuron_size, activation = activation))
    self.model = model
    self.epoch_size = int(epoch_size)
  
  def train(self, verbose = 1):
    '''
    Generates Training Data by
    1. Defining a Transmitter/Receiver for the given number of training bits, modulation and snr
    2. Maps the bits to constellation with AWGN -> This is the Training Data, X
    3. Decodes using tradition decoding -> This is the Training Data, y
    4. Trains the Neural Network using the Training Data
    '''
    self.training_system = Transmitter_Receiver(self.training_size, self.modulation)
    self.training_system.send_n_receive(self.train_snr)
    self.training_system.decode()
    self.model.add(Dense(self.training_system.k, activation='linear'))

    X = np.transpose(self.training_system.r)
    y = np.transpose(self.training_system.llr)
    self.model.compile(loss = self.loss, optimizer = self.optimizer , metrics=['mse'])
    self.model_history = self.model.fit(X, y, epochs=self.epoch_size, validation_split = 0.3, batch_size=50,callbacks= [tensorboard], verbose = verbose)
  
  def test(self, verbose = True):
    '''
    Tests the model by:
    1. Defining a Transmitter/Receiver for the given number of testing bits, modulation and snr
    2. Maps the bits to constellation with AWGN -> This is the Training Data, X
    3. Decodes using tradition decoding -> This is the 'true' value, y
    '''
    self.test_system = Transmitter_Receiver(self.test_size, self.modulation)
    self.test_system.send_n_receive(self.test_snr)
    self.test_system.decode()

    X = np.transpose(self.test_system.r)
    self.predictions = self.model.predict(X)
    self.decode = np.transpose(0.5*(-1*self.predictions/np.abs(self.predictions)+1))
    self.num_error = np.sum(np.abs(self.test_system.bit_stream-self.decode))
    self.b_error = self.num_error/self.test_system.num_bits_send
    self.conventional_error = self.test_system.bit_error/self.test_system.num_bits_send
    self.accuracy = 1- np.average(np.abs(self.predictions.T - self.test_system.llr)/ np.abs(self.test_system.llr)) 
    if verbose:
      print('Conventional Decoder bit error rate is %f' %(self.conventional_error))
      print('LLR Net bit error rate is %f' %(self.b_error))

  def plot_model_history(self, history =None):
    if history is  None:
      history = self.model_history

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
    ax1.plot(history.history['mse'])
    ax1.plot(history.history['val_mse'])
    ax1.set_title('model MSE')
    ax1.set_ylabel('MSE')
    ax1.set_xlabel('epoch')
    ax1.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# # Verification of LLRnet's accuracy with matching training/testing SNR
# Following are plots ranging from -10dB to 20dB SNR to compare the bit-error rates of the conventional decoder versus the llr-net decoder. Note that the training and testing are done at the same SNR.

# %%
a = LLR_net('64QAM', 5000, 10000, train_snr = 0, test_snr = 5, activation = 'relu')
a.model.summary()
# Out:
# Model: "sequential_578"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1732 (Dense)          (None, 16)                48
#
#  dropout_584 (Dropout)       (None, 16)                0
#
#  dense_1733 (Dense)          (None, 16)                272
#
# =================================================================
# Total params: 320
# Trainable params: 320
# Non-trainable params: 0
# _________________________________________________________________

# %%
SNR_Range = [-10,31] # 0,31
spacing = 1
snr_list = np.linspace(SNR_Range[0],SNR_Range[1],int(np.abs(SNR_Range[0]-SNR_Range[1])*1/spacing)+1)

# modulation_list = ['BPSK','4QAM', '16QAM', '64QAM']
modulation_list = [ '64QAM']
llr_net_accuracy = [[] for i in modulation_list]

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]
train_snr = 25
for n, modulation in enumerate(modulation_list):
  a = LLR_net(modulation, 20000, 10000, train_snr = train_snr, activation = 'relu',neuron_size=32)
  a.epoch_size = 50
  a.train()
  for snr in snr_list:
    # a = LLR_net(modulation, 10000, 20000, train_snr = snr, test_snr = snr, activation = 'relu')
    # a.train()
    a.test_snr = snr
    a.test()
    llr_net_accuracy[n].append(a.accuracy)
  axes[n].plot(snr_list, llr_net_accuracy[n], linewidth = 5, label = 'Neural Net Accuracy')
  axes[n].set_title(modulation)
  axes[n].set_ylim((0,1))
  axes[n].set(xlabel = 'snr (dB)', ylabel = 'Accuracy')
ax1.legend()
# Out:
# Epoch 1/50
# 47/47 [==============================] - 0s 3ms/step - loss: 13.6301 - mse: 13.6301 - val_loss: 11.9015 - val_mse: 11.9015
# Epoch 2/50
# 47/47 [==============================] - 0s 1ms/step - loss: 10.6030 - mse: 10.6030 - val_loss: 8.8562 - val_mse: 8.8562
# Epoch 3/50
# 47/47 [==============================] - 0s 1ms/step - loss: 7.7317 - mse: 7.7317 - val_loss: 5.9246 - val_mse: 5.9246
# Epoch 4/50
# 47/47 [==============================] - 0s 1ms/step - loss: 5.4721 - mse: 5.4721 - val_loss: 3.9164 - val_mse: 3.9164
# Epoch 5/50
# 47/47 [==============================] - 0s 1ms/step - loss: 4.4633 - mse: 4.4633 - val_loss: 3.2137 - val_mse: 3.2137
# Epoch 6/50
# 47/47 [==============================] - 0s 1ms/step - loss: 4.0444 - mse: 4.0444 - val_loss: 2.9335 - val_mse: 2.9335
# Epoch 7/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.8435 - mse: 3.8435 - val_loss: 2.7388 - val_mse: 2.7388
# Epoch 8/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.6437 - mse: 3.6437 - val_loss: 2.5880 - val_mse: 2.5880
# Epoch 9/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.5833 - mse: 3.5833 - val_loss: 2.4904 - val_mse: 2.4904
# Epoch 10/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.4595 - mse: 3.4595 - val_loss: 2.3949 - val_mse: 2.3949
# Epoch 11/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.3109 - mse: 3.3109 - val_loss: 2.3454 - val_mse: 2.3454
# Epoch 12/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.2357 - mse: 3.2357 - val_loss: 2.2624 - val_mse: 2.2624
# Epoch 13/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.1985 - mse: 3.1985 - val_loss: 2.2021 - val_mse: 2.2021
# Epoch 14/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.2222 - mse: 3.2222 - val_loss: 2.1447 - val_mse: 2.1447
# Epoch 15/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.0430 - mse: 3.0430 - val_loss: 2.1007 - val_mse: 2.1007
# Epoch 16/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.0123 - mse: 3.0123 - val_loss: 2.0352 - val_mse: 2.0352
# Epoch 17/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.8942 - mse: 2.8942 - val_loss: 1.9735 - val_mse: 1.9735
# Epoch 18/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.8687 - mse: 2.8687 - val_loss: 1.9281 - val_mse: 1.9281
# Epoch 19/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.7918 - mse: 2.7918 - val_loss: 1.8767 - val_mse: 1.8767
# Epoch 20/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.8058 - mse: 2.8058 - val_loss: 1.8283 - val_mse: 1.8283
# Epoch 21/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.6626 - mse: 2.6626 - val_loss: 1.7968 - val_mse: 1.7968
# Epoch 22/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.5991 - mse: 2.5991 - val_loss: 1.7417 - val_mse: 1.7417
# Epoch 23/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.5736 - mse: 2.5736 - val_loss: 1.6754 - val_mse: 1.6754
# Epoch 24/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.5725 - mse: 2.5725 - val_loss: 1.6342 - val_mse: 1.6342
# Epoch 25/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4774 - mse: 2.4774 - val_loss: 1.6254 - val_mse: 1.6254
# Epoch 26/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4288 - mse: 2.4288 - val_loss: 1.5716 - val_mse: 1.5716
# Epoch 27/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4222 - mse: 2.4222 - val_loss: 1.5340 - val_mse: 1.5340
# Epoch 28/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.3491 - mse: 2.3491 - val_loss: 1.5102 - val_mse: 1.5102
# Epoch 29/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4096 - mse: 2.4096 - val_loss: 1.4576 - val_mse: 1.4576
# Epoch 30/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.3187 - mse: 2.3187 - val_loss: 1.4581 - val_mse: 1.4581
# Epoch 31/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.2390 - mse: 2.2390 - val_loss: 1.4384 - val_mse: 1.4384
# Epoch 32/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.2136 - mse: 2.2136 - val_loss: 1.3976 - val_mse: 1.3976
# Epoch 33/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.2270 - mse: 2.2270 - val_loss: 1.3683 - val_mse: 1.3683
# Epoch 34/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1982 - mse: 2.1982 - val_loss: 1.3782 - val_mse: 1.3782
# Epoch 35/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.2273 - mse: 2.2273 - val_loss: 1.3444 - val_mse: 1.3444
# Epoch 36/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1391 - mse: 2.1391 - val_loss: 1.3269 - val_mse: 1.3269
# Epoch 37/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1304 - mse: 2.1304 - val_loss: 1.3139 - val_mse: 1.3139
# Epoch 38/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1154 - mse: 2.1154 - val_loss: 1.3210 - val_mse: 1.3210
# Epoch 39/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1111 - mse: 2.1111 - val_loss: 1.2945 - val_mse: 1.2945
# Epoch 40/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0603 - mse: 2.0603 - val_loss: 1.3090 - val_mse: 1.3090
# Epoch 41/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0432 - mse: 2.0432 - val_loss: 1.2987 - val_mse: 1.2987
# Epoch 42/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0204 - mse: 2.0204 - val_loss: 1.2841 - val_mse: 1.2841
# Epoch 43/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0015 - mse: 2.0015 - val_loss: 1.2607 - val_mse: 1.2607
# Epoch 44/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0393 - mse: 2.0393 - val_loss: 1.2669 - val_mse: 1.2669
# Epoch 45/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0167 - mse: 2.0167 - val_loss: 1.2325 - val_mse: 1.2325
# Epoch 46/50
# 47/47 [==============================] - 0s 1ms/step - loss: 1.9612 - mse: 1.9612 - val_loss: 1.2249 - val_mse: 1.2249
# Epoch 47/50
# 47/47 [==============================] - 0s 2ms/step - loss: 1.9769 - mse: 1.9769 - val_loss: 1.2689 - val_mse: 1.2689
# Epoch 48/50
# 47/47 [==============================] - 0s 1ms/step - loss: 1.9880 - mse: 1.9880 - val_loss: 1.2369 - val_mse: 1.2369
# Epoch 49/50
# 47/47 [==============================] - 0s 1ms/step - loss: 1.9110 - mse: 1.9110 - val_loss: 1.2313 - val_mse: 1.2313
# Epoch 50/50
# 47/47 [==============================] - 0s 1ms/step - loss: 1.8789 - mse: 1.8789 - val_loss: 1.2190 - val_mse: 1.2190
# 53/53 [==============================] - 0s 446us/step
# Conventional Decoder bit error rate is 0.394621
# LLR Net bit error rate is 0.393021
# 53/53 [==============================] - 0s 431us/step
# Conventional Decoder bit error rate is 0.378024
# LLR Net bit error rate is 0.382324
# 53/53 [==============================] - 0s 410us/step
# Conventional Decoder bit error rate is 0.366127
# LLR Net bit error rate is 0.369226
# 53/53 [==============================] - 0s 404us/step
# Conventional Decoder bit error rate is 0.349030
# LLR Net bit error rate is 0.350230
# 53/53 [==============================] - 0s 409us/step
# Conventional Decoder bit error rate is 0.330934
# LLR Net bit error rate is 0.327534
# 53/53 [==============================] - 0s 416us/step
# Conventional Decoder bit error rate is 0.312937
# LLR Net bit error rate is 0.316637
# 53/53 [==============================] - 0s 412us/step
# Conventional Decoder bit error rate is 0.288242
# LLR Net bit error rate is 0.297441
# 53/53 [==============================] - 0s 410us/step
# Conventional Decoder bit error rate is 0.264647
# LLR Net bit error rate is 0.274345
# 53/53 [==============================] - 0s 407us/step
# Conventional Decoder bit error rate is 0.242851
# LLR Net bit error rate is 0.258048
# 53/53 [==============================] - 0s 413us/step
# Conventional Decoder bit error rate is 0.218356
# LLR Net bit error rate is 0.238452
# 53/53 [==============================] - 0s 419us/step
# Conventional Decoder bit error rate is 0.190062
# LLR Net bit error rate is 0.215257
# 53/53 [==============================] - 0s 408us/step
# Conventional Decoder bit error rate is 0.176965
# LLR Net bit error rate is 0.204359
# 53/53 [==============================] - 0s 412us/step
# Conventional Decoder bit error rate is 0.158068
# LLR Net bit error rate is 0.187562
# 53/53 [==============================] - 0s 479us/step
# Conventional Decoder bit error rate is 0.135173
# LLR Net bit error rate is 0.171766
# 53/53 [==============================] - 0s 397us/step
# Conventional Decoder bit error rate is 0.122775
# LLR Net bit error rate is 0.161868
# 53/53 [==============================] - 0s 398us/step
# Conventional Decoder bit error rate is 0.102679
# LLR Net bit error rate is 0.144071
# 53/53 [==============================] - 0s 408us/step
# Conventional Decoder bit error rate is 0.084183
# LLR Net bit error rate is 0.135473
# 53/53 [==============================] - 0s 414us/step
# Conventional Decoder bit error rate is 0.067686
# LLR Net bit error rate is 0.122575
# 53/53 [==============================] - 0s 404us/step
# Conventional Decoder bit error rate is 0.056089
# LLR Net bit error rate is 0.113077
# 53/53 [==============================] - 0s 401us/step
# Conventional Decoder bit error rate is 0.035993
# LLR Net bit error rate is 0.106079
# 53/53 [==============================] - 0s 420us/step
# Conventional Decoder bit error rate is 0.028194
# LLR Net bit error rate is 0.096981
# 53/53 [==============================] - 0s 418us/step
# Conventional Decoder bit error rate is 0.016197
# LLR Net bit error rate is 0.091582
# 53/53 [==============================] - 0s 408us/step
# Conventional Decoder bit error rate is 0.007598
# LLR Net bit error rate is 0.082883
# 53/53 [==============================] - 0s 431us/step
# Conventional Decoder bit error rate is 0.004199
# LLR Net bit error rate is 0.083783
# 53/53 [==============================] - 0s 541us/step
# Conventional Decoder bit error rate is 0.001900
# LLR Net bit error rate is 0.078184
# 53/53 [==============================] - 0s 400us/step
# Conventional Decoder bit error rate is 0.001200
# LLR Net bit error rate is 0.076785
# 53/53 [==============================] - 0s 405us/step
# Conventional Decoder bit error rate is 0.000100
# LLR Net bit error rate is 0.073685
# 53/53 [==============================] - 0s 401us/step
# Conventional Decoder bit error rate is 0.000100
# LLR Net bit error rate is 0.068886
# 53/53 [==============================] - 0s 390us/step
# Conventional Decoder bit error rate is 0.000100
# LLR Net bit error rate is 0.072386
# 53/53 [==============================] - 0s 413us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.066687
# 53/53 [==============================] - 0s 405us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.066487
# 53/53 [==============================] - 0s 595us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.066687
# 53/53 [==============================] - 0s 399us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.069886
# 53/53 [==============================] - 0s 478us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.067487
# 53/53 [==============================] - 0s 430us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.067986
# 53/53 [==============================] - 0s 420us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.064387
# 53/53 [==============================] - 0s 447us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.067886
# 53/53 [==============================] - 0s 416us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.063887
# 53/53 [==============================] - 0s 396us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.063687
# 53/53 [==============================] - 0s 448us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.066787
# 53/53 [==============================] - 0s 410us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.065987
# 53/53 [==============================] - 0s 406us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.067487

# %%
# Plot accuracy graph
history = a.model_history
a.plot_model_history(history)

# %%
SNR_Range = [-10,31] # 0,31
spacing = 1
snr_list = np.linspace(SNR_Range[0],SNR_Range[1],int(np.abs(SNR_Range[0]-SNR_Range[1])*1/spacing)+1)

llr_conventional = [[] for i in modulation_list]
conventional_error = [[] for i in modulation_list]
th_error = [[] for i in modulation_list]

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]

# modulation_list = ['BPSK','4QAM', '16QAM', '64QAM']
modulation_list = [ '64QAM']
llr_net_accuracy = [[] for i in modulation_list]

train_snr = 25
for n, modulation in enumerate(modulation_list):
  a = LLR_net(modulation, 20000, 10000, train_snr = train_snr, activation = 'relu',neuron_size=32)
  a.epoch_size = 50
  a.train()
  for snr in snr_list:
    # a = LLR_net(modulation, 10000, 20000, train_snr = snr, test_snr = snr, activation = 'relu')
    # a.train()
    a.test_snr = snr
    a.test()
    llr_net_accuracy[n].append(a.accuracy)
    llr_conventional[n].append(a.b_error)
    conventional_error[n].append(a.conventional_error)
    th_error[n].append(theoretical_bit_error_rate(modulation, snr))
  axes[n].semilogy(snr_list, llr_conventional[n], linewidth = 5, label = 'Neural Net BER')
  axes[n].semilogy(snr_list, conventional_error[n], label = 'Conventional BER')
  axes[n].semilogy(snr_list, th_error[n], label = 'Theoretical BER')
  axes[n].set_title(modulation)
  axes[n].set(xlabel = 'snr (dB)', ylabel = 'Bit Error Rate')
ax1.legend()
# Out:
# Epoch 1/50
# 47/47 [==============================] - 0s 3ms/step - loss: 11.9440 - mse: 11.9440 - val_loss: 10.5249 - val_mse: 10.5249
# Epoch 2/50
# 47/47 [==============================] - 0s 1ms/step - loss: 9.4783 - mse: 9.4783 - val_loss: 7.7841 - val_mse: 7.7841
# Epoch 3/50
# 47/47 [==============================] - 0s 1ms/step - loss: 7.3347 - mse: 7.3347 - val_loss: 5.7105 - val_mse: 5.7105
# Epoch 4/50
# 47/47 [==============================] - 0s 1ms/step - loss: 5.6835 - mse: 5.6835 - val_loss: 4.2209 - val_mse: 4.2209
# Epoch 5/50
# 47/47 [==============================] - 0s 1ms/step - loss: 4.6588 - mse: 4.6588 - val_loss: 3.3571 - val_mse: 3.3571
# Epoch 6/50
# 47/47 [==============================] - 0s 1ms/step - loss: 4.1271 - mse: 4.1271 - val_loss: 2.9164 - val_mse: 2.9164
# Epoch 7/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.7762 - mse: 3.7762 - val_loss: 2.6900 - val_mse: 2.6900
# Epoch 8/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.6492 - mse: 3.6492 - val_loss: 2.5584 - val_mse: 2.5584
# Epoch 9/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.4832 - mse: 3.4832 - val_loss: 2.4679 - val_mse: 2.4679
# Epoch 10/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.4135 - mse: 3.4135 - val_loss: 2.3679 - val_mse: 2.3679
# Epoch 11/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.3095 - mse: 3.3095 - val_loss: 2.3063 - val_mse: 2.3063
# Epoch 12/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.2618 - mse: 3.2618 - val_loss: 2.2315 - val_mse: 2.2315
# Epoch 13/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.1023 - mse: 3.1023 - val_loss: 2.1732 - val_mse: 2.1732
# Epoch 14/50
# 47/47 [==============================] - 0s 1ms/step - loss: 3.0015 - mse: 3.0015 - val_loss: 2.1059 - val_mse: 2.1059
# Epoch 15/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.9962 - mse: 2.9962 - val_loss: 2.0323 - val_mse: 2.0323
# Epoch 16/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.9246 - mse: 2.9246 - val_loss: 1.9527 - val_mse: 1.9527
# Epoch 17/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.8779 - mse: 2.8779 - val_loss: 1.8894 - val_mse: 1.8894
# Epoch 18/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.7311 - mse: 2.7311 - val_loss: 1.8295 - val_mse: 1.8295
# Epoch 19/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.7187 - mse: 2.7187 - val_loss: 1.7646 - val_mse: 1.7646
# Epoch 20/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.7257 - mse: 2.7257 - val_loss: 1.7192 - val_mse: 1.7192
# Epoch 21/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.5558 - mse: 2.5558 - val_loss: 1.6849 - val_mse: 1.6849
# Epoch 22/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.5555 - mse: 2.5555 - val_loss: 1.6506 - val_mse: 1.6506
# Epoch 23/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.5015 - mse: 2.5015 - val_loss: 1.6176 - val_mse: 1.6176
# Epoch 24/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4569 - mse: 2.4569 - val_loss: 1.5613 - val_mse: 1.5613
# Epoch 25/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4336 - mse: 2.4336 - val_loss: 1.5279 - val_mse: 1.5279
# Epoch 26/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.4601 - mse: 2.4601 - val_loss: 1.5037 - val_mse: 1.5037
# Epoch 27/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.3918 - mse: 2.3918 - val_loss: 1.4734 - val_mse: 1.4734
# Epoch 28/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.3539 - mse: 2.3539 - val_loss: 1.4555 - val_mse: 1.4555
# Epoch 29/50
# 47/47 [==============================] - 0s 2ms/step - loss: 2.2938 - mse: 2.2938 - val_loss: 1.4341 - val_mse: 1.4341
# Epoch 30/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.3337 - mse: 2.3337 - val_loss: 1.4239 - val_mse: 1.4239
# Epoch 31/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.3384 - mse: 2.3384 - val_loss: 1.3951 - val_mse: 1.3951
# Epoch 32/50
# 47/47 [==============================] - 0s 2ms/step - loss: 2.2489 - mse: 2.2489 - val_loss: 1.3735 - val_mse: 1.3735
# Epoch 33/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.2898 - mse: 2.2898 - val_loss: 1.3786 - val_mse: 1.3786
# Epoch 34/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1876 - mse: 2.1876 - val_loss: 1.3513 - val_mse: 1.3513
# Epoch 35/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1903 - mse: 2.1903 - val_loss: 1.3400 - val_mse: 1.3400
# Epoch 36/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1952 - mse: 2.1952 - val_loss: 1.3370 - val_mse: 1.3370
# Epoch 37/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1831 - mse: 2.1831 - val_loss: 1.3077 - val_mse: 1.3077
# Epoch 38/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1490 - mse: 2.1490 - val_loss: 1.3023 - val_mse: 1.3023
# Epoch 39/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1232 - mse: 2.1232 - val_loss: 1.2819 - val_mse: 1.2819
# Epoch 40/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1414 - mse: 2.1414 - val_loss: 1.2728 - val_mse: 1.2728
# Epoch 41/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1117 - mse: 2.1117 - val_loss: 1.2655 - val_mse: 1.2655
# Epoch 42/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1462 - mse: 2.1462 - val_loss: 1.2534 - val_mse: 1.2534
# Epoch 43/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0855 - mse: 2.0855 - val_loss: 1.2639 - val_mse: 1.2639
# Epoch 44/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0441 - mse: 2.0441 - val_loss: 1.2354 - val_mse: 1.2354
# Epoch 45/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0774 - mse: 2.0774 - val_loss: 1.2156 - val_mse: 1.2156
# Epoch 46/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.1124 - mse: 2.1124 - val_loss: 1.2132 - val_mse: 1.2132
# Epoch 47/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0198 - mse: 2.0198 - val_loss: 1.2231 - val_mse: 1.2231
# Epoch 48/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0060 - mse: 2.0060 - val_loss: 1.2208 - val_mse: 1.2208
# Epoch 49/50
# 47/47 [==============================] - 0s 1ms/step - loss: 2.0440 - mse: 2.0440 - val_loss: 1.1923 - val_mse: 1.1923
# Epoch 50/50
# 47/47 [==============================] - 0s 1ms/step - loss: 1.9451 - mse: 1.9451 - val_loss: 1.1772 - val_mse: 1.1772
# 53/53 [==============================] - 0s 453us/step
# Conventional Decoder bit error rate is 0.398820
# LLR Net bit error rate is 0.397820
# 53/53 [==============================] - 0s 443us/step
# Conventional Decoder bit error rate is 0.379624
# LLR Net bit error rate is 0.376525
# 53/53 [==============================] - 0s 414us/step
# Conventional Decoder bit error rate is 0.366027
# LLR Net bit error rate is 0.366427
# 53/53 [==============================] - 0s 430us/step
# Conventional Decoder bit error rate is 0.342831
# LLR Net bit error rate is 0.344331
# 53/53 [==============================] - 0s 405us/step
# Conventional Decoder bit error rate is 0.324835
# LLR Net bit error rate is 0.333333
# 53/53 [==============================] - 0s 436us/step
# Conventional Decoder bit error rate is 0.314837
# LLR Net bit error rate is 0.317636
# 53/53 [==============================] - 0s 463us/step
# Conventional Decoder bit error rate is 0.281744
# LLR Net bit error rate is 0.288242
# 53/53 [==============================] - 0s 399us/step
# Conventional Decoder bit error rate is 0.270146
# LLR Net bit error rate is 0.282843
# 53/53 [==============================] - 0s 401us/step
# Conventional Decoder bit error rate is 0.248950
# LLR Net bit error rate is 0.265447
# 53/53 [==============================] - 0s 391us/step
# Conventional Decoder bit error rate is 0.229354
# LLR Net bit error rate is 0.242851
# 53/53 [==============================] - 0s 402us/step
# Conventional Decoder bit error rate is 0.196561
# LLR Net bit error rate is 0.221756
# 53/53 [==============================] - 0s 399us/step
# Conventional Decoder bit error rate is 0.179764
# LLR Net bit error rate is 0.207059
# 53/53 [==============================] - 0s 443us/step
# Conventional Decoder bit error rate is 0.158968
# LLR Net bit error rate is 0.188462
# 53/53 [==============================] - 0s 397us/step
# Conventional Decoder bit error rate is 0.135973
# LLR Net bit error rate is 0.170466
# 53/53 [==============================] - 0s 404us/step
# Conventional Decoder bit error rate is 0.116677
# LLR Net bit error rate is 0.161068
# 53/53 [==============================] - 0s 414us/step
# Conventional Decoder bit error rate is 0.105779
# LLR Net bit error rate is 0.148470
# 53/53 [==============================] - 0s 415us/step
# Conventional Decoder bit error rate is 0.082484
# LLR Net bit error rate is 0.132174
# 53/53 [==============================] - 0s 426us/step
# Conventional Decoder bit error rate is 0.064787
# LLR Net bit error rate is 0.126575
# 53/53 [==============================] - 0s 414us/step
# Conventional Decoder bit error rate is 0.053189
# LLR Net bit error rate is 0.119576
# 53/53 [==============================] - 0s 400us/step
# Conventional Decoder bit error rate is 0.038392
# LLR Net bit error rate is 0.108378
# 53/53 [==============================] - 0s 409us/step
# Conventional Decoder bit error rate is 0.028194
# LLR Net bit error rate is 0.095881
# 53/53 [==============================] - 0s 422us/step
# Conventional Decoder bit error rate is 0.017097
# LLR Net bit error rate is 0.095481
# 53/53 [==============================] - 0s 420us/step
# Conventional Decoder bit error rate is 0.009798
# LLR Net bit error rate is 0.084883
# 53/53 [==============================] - 0s 402us/step
# Conventional Decoder bit error rate is 0.004299
# LLR Net bit error rate is 0.080784
# 53/53 [==============================] - 0s 415us/step
# Conventional Decoder bit error rate is 0.002300
# LLR Net bit error rate is 0.078784
# 53/53 [==============================] - 0s 401us/step
# Conventional Decoder bit error rate is 0.000800
# LLR Net bit error rate is 0.084283
# 53/53 [==============================] - 0s 410us/step
# Conventional Decoder bit error rate is 0.000100
# LLR Net bit error rate is 0.082783
# 53/53 [==============================] - 0s 403us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.078784
# 53/53 [==============================] - 0s 388us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.077784
# 53/53 [==============================] - 0s 411us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.079284
# 53/53 [==============================] - 0s 415us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.077185
# 53/53 [==============================] - 0s 396us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.078984
# 53/53 [==============================] - 0s 426us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.078484
# 53/53 [==============================] - 0s 411us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.079084
# 53/53 [==============================] - 0s 415us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.078584
# 53/53 [==============================] - 0s 392us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.076885
# 53/53 [==============================] - 0s 407us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.076485
# 53/53 [==============================] - 0s 392us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.078684
# 53/53 [==============================] - 0s 410us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.078884
# 53/53 [==============================] - 0s 412us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.083483
# 53/53 [==============================] - 0s 397us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.079984
# 53/53 [==============================] - 0s 409us/step
# Conventional Decoder bit error rate is 0.000000
# LLR Net bit error rate is 0.081284

# %%
SNR_Range = [-10,31] # 0,31
spacing = 1
snr_list = np.linspace(SNR_Range[0],SNR_Range[1],int(np.abs(SNR_Range[0]-SNR_Range[1])*1/spacing)+1)
modulation_list = ['BPSK','4QAM', '16QAM', '64QAM']
llr_conventional = [[] for i in modulation_list]
conventional_error = [[] for i in modulation_list]
th_error = [[] for i in modulation_list]

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]

for n, modulation in enumerate(modulation_list):
  for snr in snr_list:
    a = LLR_net(modulation, 5000, 10000, train_snr = snr, test_snr = snr, activation = 'tanh')
    a.train()
    a.test()
    llr_conventional[n].append(a.b_error)
    conventional_error[n].append(a.conventional_error)
    th_error[n].append(theoretical_bit_error_rate(modulation, snr))
  axes[n].semilogy(snr_list, llr_conventional[n], linewidth = 5, label = 'Neural Net BER')
  axes[n].semilogy(snr_list, conventional_error[n], label = 'Conventional BER')
  axes[n].semilogy(snr_list, th_error[n], label = 'Theoretical BER')
  axes[n].set_title(modulation)
  axes[n].set(xlabel = 'snr (dB)', ylabel = 'Bit Error Rate')
ax1.legend()
# Out:
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 405us/step
# 313/313 [==============================] - 0s 401us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 419us/step
# 313/313 [==============================] - 0s 438us/step
# 313/313 [==============================] - 0s 442us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 412us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 401us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 421us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 401us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 410us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 423us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 417us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 416us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 412us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 403us/step
# 79/79 [==============================] - 0s 419us/step
# 79/79 [==============================] - 0s 432us/step
# 79/79 [==============================] - 0s 435us/step
# 79/79 [==============================] - 0s 453us/step
# 79/79 [==============================] - 0s 420us/step
# 79/79 [==============================] - 0s 417us/step
# 79/79 [==============================] - 0s 423us/step
# 79/79 [==============================] - 0s 415us/step
# 79/79 [==============================] - 0s 461us/step
# 79/79 [==============================] - 0s 428us/step
# 79/79 [==============================] - 0s 441us/step
# 79/79 [==============================] - 0s 419us/step
# 79/79 [==============================] - 0s 415us/step
# 79/79 [==============================] - 0s 433us/step
# 79/79 [==============================] - 0s 416us/step
# 79/79 [==============================] - 0s 421us/step
# 79/79 [==============================] - 0s 404us/step
# 79/79 [==============================] - 0s 440us/step
# 79/79 [==============================] - 0s 463us/step
# 79/79 [==============================] - 0s 485us/step
# 79/79 [==============================] - 0s 439us/step
# 79/79 [==============================] - 0s 419us/step
# 79/79 [==============================] - 0s 423us/step
# 79/79 [==============================] - 0s 539us/step
# 79/79 [==============================] - 0s 422us/step
# 79/79 [==============================] - 0s 407us/step
# 79/79 [==============================] - 0s 412us/step
# 79/79 [==============================] - 0s 454us/step
# 79/79 [==============================] - 0s 421us/step
# 79/79 [==============================] - 0s 565us/step
# 79/79 [==============================] - 0s 411us/step
# 79/79 [==============================] - 0s 419us/step
# 79/79 [==============================] - 0s 427us/step
# 79/79 [==============================] - 0s 439us/step
# 79/79 [==============================] - 0s 431us/step
# 79/79 [==============================] - 0s 449us/step
# 79/79 [==============================] - 0s 426us/step
# 79/79 [==============================] - 0s 425us/step
# 79/79 [==============================] - 0s 422us/step
# 79/79 [==============================] - 0s 426us/step
# 79/79 [==============================] - 0s 500us/step
# 79/79 [==============================] - 0s 501us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 469us/step
# 53/53 [==============================] - 0s 416us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 414us/step
# 53/53 [==============================] - 0s 435us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 448us/step
# 53/53 [==============================] - 0s 410us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 410us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 407us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 422us/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 415us/step
# 53/53 [==============================] - 0s 404us/step
# 53/53 [==============================] - 0s 450us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 433us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 443us/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 433us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 549us/step
# 53/53 [==============================] - 0s 499us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 514us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 423us/step
# 53/53 [==============================] - 0s 419us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 418us/step
# 53/53 [==============================] - 0s 431us/step
# 53/53 [==============================] - 0s 484us/step

# %% [markdown]
# # Verification of LLRnet's accuracy with mixed training/testing SNR
# Following are plots ranging from mixed -10dB to 20dB SNR to compare the bit-error rates of the conventional decoder versus the llr-net decoder. Note that the training and testing are done at the same SNR. The legend is identical to above

# %%
test_snr_list = np.linspace(-10, 20, 10)
SNR_Range = [-10,31] # 0,31
spacing = 1
test_snr_list = np.linspace(SNR_Range[0],SNR_Range[1],int(np.abs(SNR_Range[0]-SNR_Range[1])*1/spacing)+1)

# %%
SNR_Range = [-10,31] # 0,31
spacing = 1
test_snr_list = np.linspace(SNR_Range[0],SNR_Range[1],int(np.abs(SNR_Range[0]-SNR_Range[1])*1/spacing)+1)
train_snr_list = np.array([-10, -5, 0, 5, 10, 15, 20, 25, 30])

modulation_list = ['BPSK', '4QAM', '16QAM', '64QAM']

fig, ((ax1, ax2, ax3, ax4),
      (ax6, ax7, ax8, ax9),
      (ax11, ax12, ax13, ax14),
      (ax16, ax17, ax18, ax19),
      (ax21, ax22, ax23, ax24),
      (ax31, ax32, ax33, ax34),
      (ax41, ax42, ax43, ax44),
      (ax51, ax52, ax53, ax54),
      (ax61, ax62, ax63, ax64)
      ) = plt.subplots(9,4, figsize = (100,25))

axes = [[ax1, ax2, ax3, ax4],
        [ax6, ax7, ax8, ax9],
        [ax11, ax12, ax13, ax14],
        [ax16, ax17, ax18, ax19],
        [ax21, ax22, ax23, ax24],
        [ax31, ax32, ax33, ax34],
        [ax41, ax42, ax43, ax44],
        [ax51, ax52, ax53, ax54],
        [ax61, ax62, ax63, ax64]
        ]

for i, modulation in enumerate(modulation_list):
  for j, train_snr in enumerate(train_snr_list):
    llr_net_error = []; conventional_error = []; th_error = []
    for n, test_snr in enumerate(test_snr_list):
        if n == 0:
          a = LLR_net(modulation, 5000, 10000, train_snr = train_snr, test_snr = test_snr, activation = 'tanh')
          a.train()
        a.test_snr = test_snr
        a.test()
        llr_net_error.append(a.b_error)
        conventional_error.append(a.conventional_error)
        th_error.append(theoretical_bit_error_rate(modulation, test_snr))

    axes[j][i].semilogy(test_snr_list, llr_net_error, linewidth = 5, label = 'Neural Net BER')
    axes[j][i].semilogy(test_snr_list, conventional_error, label = 'Conventional BER')
    axes[j][i].semilogy(test_snr_list, th_error, label = 'Theoretical BER')
    if i == 0:
      axes[j][i].set_title('Train SNR: ' + str(train_snr))
    if j == 0:
      axes[j][i].set(ylabel = modulation + 'Bit Error Rate')
      axes[j][i].legend()
    if i == 9:
      axes[j][i].set(xlabel = 'snr (dB)')
# Out:
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 377us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 380us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 378us/step
# 313/313 [==============================] - 0s 410us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 379us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 429us/step
# 313/313 [==============================] - 0s 459us/step
# 313/313 [==============================] - 0s 466us/step
# 313/313 [==============================] - 0s 429us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 472us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 374us/step
# 313/313 [==============================] - 0s 376us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 379us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 449us/step
# 313/313 [==============================] - 0s 503us/step
# 313/313 [==============================] - 0s 424us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 451us/step
# 313/313 [==============================] - 0s 432us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 447us/step
# 313/313 [==============================] - 0s 416us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 418us/step
# 313/313 [==============================] - 0s 465us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 430us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 410us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 407us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 408us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 410us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 411us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 377us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 379us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 376us/step
# 313/313 [==============================] - 0s 423us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 406us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 440us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 415us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 436us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 412us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 407us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 405us/step
# 313/313 [==============================] - 0s 430us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 419us/step
# 313/313 [==============================] - 0s 439us/step
# 313/313 [==============================] - 0s 423us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 406us/step
# 313/313 [==============================] - 0s 421us/step
# 313/313 [==============================] - 0s 430us/step
# 313/313 [==============================] - 0s 437us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 407us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 419us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 426us/step
# 313/313 [==============================] - 0s 431us/step
# 313/313 [==============================] - 0s 406us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 448us/step
# 313/313 [==============================] - 0s 413us/step
# 313/313 [==============================] - 0s 433us/step
# 313/313 [==============================] - 0s 421us/step
# 313/313 [==============================] - 0s 450us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 408us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 446us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 451us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 404us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 417us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 406us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 401us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 379us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 403us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 376us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 383us/step
# 313/313 [==============================] - 0s 379us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 405us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 405us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 442us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 380us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 380us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 371us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 422us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 388us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 400us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 390us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 389us/step
# 313/313 [==============================] - 0s 399us/step
# 313/313 [==============================] - 0s 394us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 398us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 376us/step
# 313/313 [==============================] - 0s 395us/step
# 313/313 [==============================] - 0s 391us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 396us/step
# 313/313 [==============================] - 0s 392us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 397us/step
# 313/313 [==============================] - 0s 393us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 385us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 382us/step
# 313/313 [==============================] - 0s 387us/step
# 313/313 [==============================] - 0s 379us/step
# 313/313 [==============================] - 0s 374us/step
# 313/313 [==============================] - 0s 384us/step
# 313/313 [==============================] - 0s 402us/step
# 313/313 [==============================] - 0s 381us/step
# 313/313 [==============================] - 0s 386us/step
# 313/313 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 484us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 382us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 410us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 416us/step
# 157/157 [==============================] - 0s 413us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 382us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 431us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 382us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 462us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 380us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 378us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 407us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 410us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 417us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 384us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 411us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 413us/step
# 157/157 [==============================] - 0s 407us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 464us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 387us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 382us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 387us/step
# 157/157 [==============================] - 0s 384us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 412us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 387us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 410us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 387us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 435us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 410us/step
# 157/157 [==============================] - 0s 430us/step
# 157/157 [==============================] - 0s 444us/step
# 157/157 [==============================] - 0s 434us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 411us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 413us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 384us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 420us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 415us/step
# 157/157 [==============================] - 0s 444us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 443us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 407us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 407us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 418us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 385us/step
# 157/157 [==============================] - 0s 472us/step
# 157/157 [==============================] - 0s 420us/step
# 157/157 [==============================] - 0s 482us/step
# 157/157 [==============================] - 0s 447us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 467us/step
# 157/157 [==============================] - 0s 446us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 435us/step
# 157/157 [==============================] - 0s 450us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 454us/step
# 157/157 [==============================] - 0s 427us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 439us/step
# 157/157 [==============================] - 0s 418us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 449us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 415us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 424us/step
# 157/157 [==============================] - 0s 387us/step
# 157/157 [==============================] - 0s 393us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 418us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 424us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 417us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 401us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 458us/step
# 157/157 [==============================] - 0s 429us/step
# 157/157 [==============================] - 0s 417us/step
# 157/157 [==============================] - 0s 433us/step
# 157/157 [==============================] - 0s 408us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 427us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 441us/step
# 157/157 [==============================] - 0s 386us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 388us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 411us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 417us/step
# 157/157 [==============================] - 0s 426us/step
# 157/157 [==============================] - 0s 433us/step
# 157/157 [==============================] - 0s 450us/step
# 157/157 [==============================] - 0s 423us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 411us/step
# 157/157 [==============================] - 0s 407us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 440us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 398us/step
# 157/157 [==============================] - 0s 391us/step
# 157/157 [==============================] - 0s 397us/step
# 157/157 [==============================] - 0s 410us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 420us/step
# 157/157 [==============================] - 0s 395us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 414us/step
# 157/157 [==============================] - 0s 409us/step
# 157/157 [==============================] - 0s 405us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 406us/step
# 157/157 [==============================] - 0s 421us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 396us/step
# 157/157 [==============================] - 0s 390us/step
# 157/157 [==============================] - 0s 400us/step
# 157/157 [==============================] - 0s 382us/step
# 157/157 [==============================] - 0s 392us/step
# 157/157 [==============================] - 0s 394us/step
# 157/157 [==============================] - 0s 402us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 421us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 389us/step
# 157/157 [==============================] - 0s 407us/step
# 157/157 [==============================] - 0s 403us/step
# 157/157 [==============================] - 0s 427us/step
# 157/157 [==============================] - 0s 399us/step
# 157/157 [==============================] - 0s 383us/step
# 157/157 [==============================] - 0s 412us/step
# 157/157 [==============================] - 0s 419us/step
# 157/157 [==============================] - 0s 422us/step
# 157/157 [==============================] - 0s 404us/step
# 157/157 [==============================] - 0s 412us/step
# 79/79 [==============================] - 0s 403us/step
# 79/79 [==============================] - 0s 404us/step
# 79/79 [==============================] - 0s 397us/step
# 79/79 [==============================] - 0s 406us/step
# 79/79 [==============================] - 0s 416us/step
# 79/79 [==============================] - 0s 421us/step
# 79/79 [==============================] - 0s 396us/step
# 79/79 [==============================] - 0s 392us/step
# 79/79 [==============================] - 0s 407us/step
# 79/79 [==============================] - 0s 401us/step
# 79/79 [==============================] - 0s 395us/step
# 79/79 [==============================] - 0s 389us/step
# 79/79 [==============================] - 0s 396us/step
# 79/79 [==============================] - 0s 395us/step
# 79/79 [==============================] - 0s 425us/step
# 79/79 [==============================] - 0s 405us/step
# 79/79 [==============================] - 0s 389us/step
# 79/79 [==============================] - 0s 390us/step
# 79/79 [==============================] - 0s 402us/step
# 79/79 [==============================] - 0s 426us/step
# 79/79 [==============================] - 0s 411us/step
# 79/79 [==============================] - 0s 395us/step
# 79/79 [==============================] - 0s 400us/step
# 79/79 [==============================] - 0s 401us/step
# 79/79 [==============================] - 0s 407us/step
# 79/79 [==============================] - 0s 397us/step
# 79/79 [==============================] - 0s 395us/step
# 79/79 [==============================] - 0s 401us/step
# 79/79 [==============================] - 0s 419us/step
# 79/79 [==============================] - 0s 410us/step
# 79/79 [==============================] - 0s 398us/step
# 79/79 [==============================] - 0s 401us/step
# 79/79 [==============================] - 0s 392us/step
# 79/79 [==============================] - 0s 398us/step
# 79/79 [==============================] - 0s 411us/step
# 79/79 [==============================] - 0s 395us/step
# 79/79 [==============================] - 0s 389us/step
# 79/79 [==============================] - 0s 397us/step
# 79/79 [==============================] - 0s 415us/step
# 79/79 [==============================] - 0s 397us/step
# 79/79 [==============================] - 0s 389us/step
# 79/79 [==============================] - 0s 413us/step
# 79/79 [==============================] - 0s 406us/step
# 79/79 [==============================] - 0s 394us/step
# 79/79 [==============================] - 0s 394us/step
# 79/79 [==============================] - 0s 394us/step
# 79/79 [==============================] - 0s 403us/step
# 79/79 [==============================] - 0s 408us/step
# 79/79 [==============================] - 0s 390us/step
# 79/79 [==============================] - 0s 412us/step
# 79/79 [==============================] - 0s 435us/step
# 79/79 [==============================] - 0s 398us/step
# 79/79 [==============================] - 0s 403us/step
# 79/79 [==============================] - 0s 404us/step
# 79/79 [==============================] - 0s 392us/step
# 79/79 [==============================] - 0s 418us/step
# 79/79 [==============================] - 0s 425us/step
# 79/79 [==============================] - 0s 394us/step
# 79/79 [==============================] - 0s 405us/step
# 79/79 [==============================] - 0s 394us/step
# 79/79 [==============================] - 0s 392us/step
# 79/79 [==============================] - 0s 388us/step
# 79/79 [==============================] - 0s 411us/step
# 79/79 [==============================] - 0s 400us/step
# 79/79 [==============================] - 0s 396us/step
# 79/79 [==============================] - 0s 401us/step
# 79/79 [==============================] - 0s 409us/step
# 79/79 [==============================] - 0s 404us/step
# 79/79 [==============================] - 0s 403us/step
# 79/79 [==============================] - 0s 392us/step
# 79/79 [==============================] - 0s 405us/step
# 79/79 [==============================] - 0s 394us/step
# 79/79 [==============================] - 0s 405us/step
# 79/79 [==============================] - 0s 417us/step
# 79/79 [==============================] - 0s 396us/step
# 79/79 [==============================] - 0s 385us/step
# 79/79 [==============================] - 0s 392us/step
# 79/79 [==============================] - 0s 397us/step
# 79/79 [==============================] - 0s 401us/step
# 79/79 [==============================] - 0s 387us/step
# 79/79 [==============================] - 0s 391us/step
# 79/79 [==============================] - 0s 391us/step
# 79/79 [==============================] - 0s 389us/step
# 79/79 [==============================] - 0s 390us/step
# 79/79 [==============================] - 0s 412us/step
# 79/79 [==============================] - 0s 404us/step
# 79/79 [==============================] - 0s 395us/step
# 79/79 [==============================] - 0s 408us/step
# 79/79 [==============================] - 0s 405us/step
# ...
# 53/53 [==============================] - 0s 472us/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 437us/step
# 53/53 [==============================] - 0s 442us/step
# 53/53 [==============================] - 0s 543us/step
# 53/53 [==============================] - 0s 422us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 441us/step
# 53/53 [==============================] - 0s 461us/step
# 53/53 [==============================] - 0s 469us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 437us/step
# 53/53 [==============================] - 0s 451us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 433us/step
# 53/53 [==============================] - 0s 451us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 414us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 510us/step
# 53/53 [==============================] - 0s 470us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 448us/step
# 53/53 [==============================] - 0s 470us/step
# 53/53 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 434us/step
# 53/53 [==============================] - 0s 474us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 470us/step
# 53/53 [==============================] - 0s 423us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 460us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 484us/step
# 53/53 [==============================] - 0s 456us/step
# 53/53 [==============================] - 0s 446us/step
# 53/53 [==============================] - 0s 496us/step
# 53/53 [==============================] - 0s 442us/step
# 53/53 [==============================] - 0s 431us/step
# 53/53 [==============================] - 0s 513us/step
# 53/53 [==============================] - 0s 478us/step
# 53/53 [==============================] - 0s 431us/step
# 53/53 [==============================] - 0s 446us/step
# 53/53 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 479us/step
# 53/53 [==============================] - 0s 494us/step
# 53/53 [==============================] - 0s 450us/step
# 53/53 [==============================] - 0s 538us/step
# 53/53 [==============================] - 0s 467us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 464us/step
# 53/53 [==============================] - 0s 441us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 446us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 448us/step
# 53/53 [==============================] - 0s 463us/step
# 53/53 [==============================] - 0s 456us/step
# 53/53 [==============================] - 0s 466us/step
# 53/53 [==============================] - 0s 457us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 435us/step
# 53/53 [==============================] - 0s 467us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 420us/step
# 53/53 [==============================] - 0s 467us/step
# 53/53 [==============================] - 0s 436us/step
# 53/53 [==============================] - 0s 440us/step
# 53/53 [==============================] - 0s 475us/step
# 53/53 [==============================] - 0s 479us/step
# 53/53 [==============================] - 0s 458us/step
# 53/53 [==============================] - 0s 434us/step
# 53/53 [==============================] - 0s 486us/step
# 53/53 [==============================] - 0s 468us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 501us/step
# 53/53 [==============================] - 0s 464us/step
# 53/53 [==============================] - 0s 489us/step
# 53/53 [==============================] - 0s 464us/step
# 53/53 [==============================] - 0s 440us/step
# 53/53 [==============================] - 0s 434us/step
# 53/53 [==============================] - 0s 481us/step
# 53/53 [==============================] - 0s 579us/step
# 53/53 [==============================] - 0s 444us/step
# 53/53 [==============================] - 0s 446us/step
# 53/53 [==============================] - 0s 474us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 475us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 463us/step
# 53/53 [==============================] - 0s 466us/step
# 53/53 [==============================] - 0s 472us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 460us/step
# 53/53 [==============================] - 0s 494us/step
# 53/53 [==============================] - 0s 478us/step
# 53/53 [==============================] - 0s 458us/step
# 53/53 [==============================] - 0s 436us/step
# 53/53 [==============================] - 0s 486us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 626us/step
# 53/53 [==============================] - 0s 773us/step
# 53/53 [==============================] - 0s 627us/step
# 53/53 [==============================] - 0s 509us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 670us/step
# 53/53 [==============================] - 0s 495us/step
# 53/53 [==============================] - 0s 568us/step
# 53/53 [==============================] - 0s 468us/step
# 53/53 [==============================] - 0s 400us/step
# 53/53 [==============================] - 0s 434us/step
# 53/53 [==============================] - 0s 404us/step
# 53/53 [==============================] - 0s 407us/step
# 53/53 [==============================] - 0s 420us/step
# 53/53 [==============================] - 0s 412us/step
# 53/53 [==============================] - 0s 402us/step
# 53/53 [==============================] - 0s 417us/step
# 53/53 [==============================] - 0s 456us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 450us/step
# /tmp/ipykernel_61614/3930789453.py:54: RuntimeWarning: invalid value encountered in divide
#   self.decode = np.transpose(0.5*(-1*self.predictions/np.abs(self.predictions)+1))
# 53/53 [==============================] - 0s 471us/step
# 53/53 [==============================] - 0s 498us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 527us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 451us/step
# 53/53 [==============================] - 0s 419us/step
# 53/53 [==============================] - 0s 459us/step
# 53/53 [==============================] - 0s 442us/step
# 53/53 [==============================] - 0s 509us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 464us/step
# 53/53 [==============================] - 0s 435us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 517us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 437us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 574us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 435us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 502us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 448us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 467us/step
# 53/53 [==============================] - 0s 467us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 480us/step
# 53/53 [==============================] - 0s 420us/step
# 53/53 [==============================] - 0s 412us/step
# 53/53 [==============================] - 0s 440us/step
# 53/53 [==============================] - 0s 433us/step
# 53/53 [==============================] - 0s 471us/step
# 53/53 [==============================] - 0s 490us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 435us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 471us/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 508us/step
# 53/53 [==============================] - 0s 491us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 505us/step
# 53/53 [==============================] - 0s 493us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 440us/step
# 53/53 [==============================] - 0s 484us/step
# 53/53 [==============================] - 0s 443us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 475us/step
# 53/53 [==============================] - 0s 475us/step
# 53/53 [==============================] - 1s 11ms/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 487us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 459us/step
# 53/53 [==============================] - 0s 463us/step
# 53/53 [==============================] - 0s 496us/step
# 53/53 [==============================] - 0s 526us/step
# 53/53 [==============================] - 0s 533us/step
# 53/53 [==============================] - 0s 456us/step
# 53/53 [==============================] - 0s 487us/step
# 53/53 [==============================] - 0s 474us/step
# 53/53 [==============================] - 0s 460us/step
# 53/53 [==============================] - 0s 434us/step
# 53/53 [==============================] - 0s 460us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 471us/step
# 53/53 [==============================] - 0s 465us/step
# 53/53 [==============================] - 0s 472us/step
# 53/53 [==============================] - 0s 513us/step
# 53/53 [==============================] - 0s 486us/step
# 53/53 [==============================] - 0s 491us/step
# 53/53 [==============================] - 0s 486us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 478us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 473us/step
# 53/53 [==============================] - 0s 862us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 530us/step
# 53/53 [==============================] - 0s 463us/step
# 53/53 [==============================] - 0s 458us/step
# 53/53 [==============================] - 0s 538us/step
# 53/53 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 542us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 492us/step
# 53/53 [==============================] - 0s 508us/step
# 53/53 [==============================] - 0s 469us/step
# 53/53 [==============================] - 0s 461us/step
# 53/53 [==============================] - 0s 515us/step
# 53/53 [==============================] - 0s 467us/step
# 53/53 [==============================] - 0s 519us/step
# 53/53 [==============================] - 0s 485us/step
# 53/53 [==============================] - 0s 441us/step
# 53/53 [==============================] - 0s 471us/step
# 53/53 [==============================] - 0s 490us/step
# 53/53 [==============================] - 0s 436us/step
# 53/53 [==============================] - 0s 489us/step
# 53/53 [==============================] - 0s 490us/step
# 53/53 [==============================] - 0s 474us/step
# 53/53 [==============================] - 0s 449us/step
# 53/53 [==============================] - 0s 508us/step
# 53/53 [==============================] - 0s 604us/step
# 53/53 [==============================] - 0s 451us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 473us/step
# 53/53 [==============================] - 0s 460us/step
# 53/53 [==============================] - 0s 463us/step
# 53/53 [==============================] - 0s 423us/step
# 53/53 [==============================] - 0s 506us/step
# 53/53 [==============================] - 0s 436us/step
# 53/53 [==============================] - 0s 481us/step
# 53/53 [==============================] - 0s 442us/step
# 53/53 [==============================] - 0s 495us/step
# 53/53 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 515us/step
# 53/53 [==============================] - 0s 473us/step
# 53/53 [==============================] - 0s 419us/step
# 53/53 [==============================] - 0s 436us/step
# 53/53 [==============================] - 0s 489us/step
# 53/53 [==============================] - 0s 458us/step
# 53/53 [==============================] - 0s 470us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 466us/step
# 53/53 [==============================] - 0s 490us/step
# 53/53 [==============================] - 0s 481us/step
# 53/53 [==============================] - 0s 462us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 459us/step
# 53/53 [==============================] - 0s 457us/step
# 53/53 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 431us/step
# 53/53 [==============================] - 0s 454us/step
# 53/53 [==============================] - 0s 420us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 442us/step
# 53/53 [==============================] - 0s 494us/step
# 53/53 [==============================] - 0s 587us/step
# 53/53 [==============================] - 0s 466us/step
# 53/53 [==============================] - 0s 475us/step

# %% [markdown]
# #Model Correction with data from mixed training/testing SNR
#
# Training and testing the model and different SNRs showed that for 16QAM and 64QAM, the best results were obtained when the model was trained at high SNR. Training SNR doesn't make an difference for the other modulation schemes (BPSK, 8PSK, 4QAM).
#
# Given this information, we can make modifications to the optimal model by training the model at high SNR for all test cases.
#
# In addition, we can infer from the difference in 16QAM and 64QAM that first, the model is able to predict to some degree of success (although higher in error than the conventional decoding), and secondly, the model does worse in higher dimensional feature space. Therefore, increasing the number of epochs may help the model perform better.

# %%
train_snr = 40
epoch_size = 300

snr_list = np.linspace(-10, 20, 10)
modulation_list = ['BPSK', '4QAM', '16QAM', '64QAM']
llr_net_accuracy = [[] for i in modulation_list]

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]

for n, modulation in enumerate(modulation_list):
  a = LLR_net(modulation, 5000, 10000, train_snr = train_snr, test_snr = -10, activation = 'tanh',
              epoch_size = epoch_size)
  a.train()
  for snr in snr_list:
    a.test_snr = snr
    a.test()
    llr_net_accuracy[n].append(a.accuracy)
  axes[n].plot(snr_list, llr_net_accuracy[n], linewidth = 5, label = 'Neural Net Accuracy')
  axes[n].set_title(modulation)
  axes[n].set(xlabel = 'snr (dB)', ylabel = 'Accuracy')
ax1.legend()
# Out:
# 313/313 [==============================] - 0s 443us/step
# 313/313 [==============================] - 0s 453us/step
# 313/313 [==============================] - 0s 461us/step
# 313/313 [==============================] - 0s 455us/step
# 313/313 [==============================] - 0s 433us/step
# 313/313 [==============================] - 0s 431us/step
# 313/313 [==============================] - 0s 452us/step
# 313/313 [==============================] - 0s 430us/step
# 313/313 [==============================] - 0s 435us/step
# 313/313 [==============================] - 0s 436us/step
# 157/157 [==============================] - 0s 496us/step
# 157/157 [==============================] - 0s 442us/step
# 157/157 [==============================] - 0s 439us/step
# 157/157 [==============================] - 0s 436us/step
# 157/157 [==============================] - 0s 439us/step
# 157/157 [==============================] - 0s 439us/step
# 157/157 [==============================] - 0s 436us/step
# 157/157 [==============================] - 0s 424us/step
# 157/157 [==============================] - 0s 478us/step
# 157/157 [==============================] - 0s 456us/step
# 79/79 [==============================] - 0s 424us/step
# 79/79 [==============================] - 0s 640us/step
# 79/79 [==============================] - 0s 461us/step
# 79/79 [==============================] - 0s 457us/step
# 79/79 [==============================] - 0s 445us/step
# 79/79 [==============================] - 0s 435us/step
# 79/79 [==============================] - 0s 520us/step
# 79/79 [==============================] - 0s 520us/step
# 79/79 [==============================] - 0s 459us/step
# 79/79 [==============================] - 0s 453us/step
# 53/53 [==============================] - 0s 589us/step
# 53/53 [==============================] - 0s 471us/step
# 53/53 [==============================] - 0s 459us/step
# 53/53 [==============================] - 0s 470us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 441us/step
# 53/53 [==============================] - 0s 405us/step
# 53/53 [==============================] - 0s 444us/step
# 53/53 [==============================] - 0s 497us/step
# 53/53 [==============================] - 0s 445us/step

# %%
train_snr = 40
epoch_size = 300

snr_list = np.linspace(-10, 20, 10)
modulation_list = ['BPSK','4QAM', '16QAM', '64QAM']
llr_net_error = [[] for i in modulation_list]
conventional_error = [[] for i in modulation_list]

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]

for n, modulation in enumerate(modulation_list):
  a = LLR_net(modulation, 5000, 10000, train_snr = train_snr, test_snr = snr, activation = 'tanh', epoch_size= 300)
  a.train()
  for snr in snr_list:
    a.test_snr = snr
    a.test()
    llr_net_error[n].append(a.b_error)
    conventional_error[n].append(a.conventional_error)
  axes[n].semilogy(snr_list, llr_net_error[n], linewidth = 5)
  axes[n].semilogy(snr_list, conventional_error[n])
  axes[n].set_title(modulation)
  axes[n].set(xlabel = 'snr (dB)', ylabel = 'Bit Error Rate')
# Out:
# 313/313 [==============================] - 0s 443us/step
# 313/313 [==============================] - 0s 433us/step
# 313/313 [==============================] - 0s 436us/step
# 313/313 [==============================] - 0s 436us/step
# 313/313 [==============================] - 0s 438us/step
# 313/313 [==============================] - 0s 434us/step
# 313/313 [==============================] - 0s 436us/step
# 313/313 [==============================] - 0s 465us/step
# 313/313 [==============================] - 0s 435us/step
# 313/313 [==============================] - 0s 450us/step
# 157/157 [==============================] - 0s 456us/step
# 157/157 [==============================] - 0s 458us/step
# 157/157 [==============================] - 0s 468us/step
# 157/157 [==============================] - 0s 485us/step
# 157/157 [==============================] - 0s 430us/step
# 157/157 [==============================] - 0s 443us/step
# 157/157 [==============================] - 0s 458us/step
# 157/157 [==============================] - 0s 473us/step
# 157/157 [==============================] - 0s 431us/step
# 157/157 [==============================] - 0s 467us/step
# 79/79 [==============================] - 0s 503us/step
# 79/79 [==============================] - 0s 506us/step
# 79/79 [==============================] - 0s 471us/step
# 79/79 [==============================] - 0s 444us/step
# 79/79 [==============================] - 0s 513us/step
# 79/79 [==============================] - 0s 469us/step
# 79/79 [==============================] - 0s 537us/step
# 79/79 [==============================] - 0s 430us/step
# 79/79 [==============================] - 0s 432us/step
# 79/79 [==============================] - 0s 455us/step
# 53/53 [==============================] - 0s 488us/step
# 53/53 [==============================] - 0s 518us/step
# 53/53 [==============================] - 0s 447us/step
# 53/53 [==============================] - 0s 468us/step
# 53/53 [==============================] - 0s 458us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 454us/step
# 53/53 [==============================] - 0s 524us/step
# 53/53 [==============================] - 0s 476us/step
# 53/53 [==============================] - 0s 516us/step

# %% [markdown]
# #Effect of additional layers in Neural Net for 64QAM
#
# We have seen that LLR_net is highly effective for decoding signals in BPSK, 8PSK and 4QAM but don't work as well in 16-QAM and 64-QAM. However, training at high SNR with increased epoch size helped LLR_net be reliable at 16-QAM, but not 64-QAM.
#
# This section seeks to verify whether additional hidden layers would help decrease the bit error rate in 64QAM.
#
# Testing and simulating 64QAM LLR_net decoder for layers 1-4 showed that there was no relationship between the number of layers and bit detection performance.

# %%
snr_list = np.linspace(-10, 40, 20)
layer_num_list = [1, 2, 3, 4]
modulation = '64QAM'
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (25, 5))
axes = [ax1, ax2, ax3, ax4]
for n, layer_num in enumerate(layer_num_list):
  a = LLR_net(modulation, 5000, 10000, train_snr = 30, test_snr = 5, activation = 'tanh',
            epoch_size=300, layer_num=layer_num)
  a.train()
  llr_net_error = []; conv_error = []
  for snr in snr_list:
    a.test_snr = snr
    a.test()
    llr_net_error.append(a.b_error)
    conv_error.append(a.conventional_error)
  axes[n].semilogy(snr_list, llr_net_error, linewidth = 5)
  axes[n].semilogy(snr_list, conv_error)
  axes[n].set_title('Number of Layers: ' + str(layer_num))
  axes[n].set(xlabel = 'snr (dB)', ylabel = 'Bit Error Rate')
# Out:
# 53/53 [==============================] - 0s 446us/step
# 53/53 [==============================] - 0s 445us/step
# 53/53 [==============================] - 0s 394us/step
# 53/53 [==============================] - 0s 399us/step
# 53/53 [==============================] - 0s 405us/step
# 53/53 [==============================] - 0s 414us/step
# 53/53 [==============================] - 0s 416us/step
# 53/53 [==============================] - 0s 413us/step
# 53/53 [==============================] - 0s 399us/step
# 53/53 [==============================] - 0s 406us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 422us/step
# 53/53 [==============================] - 0s 410us/step
# 53/53 [==============================] - 0s 406us/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 417us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 414us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 439us/step
# 53/53 [==============================] - 0s 409us/step
# 53/53 [==============================] - 0s 404us/step
# 53/53 [==============================] - 0s 393us/step
# 53/53 [==============================] - 0s 409us/step
# 53/53 [==============================] - 0s 403us/step
# 53/53 [==============================] - 0s 410us/step
# 53/53 [==============================] - 0s 411us/step
# 53/53 [==============================] - 0s 412us/step
# 53/53 [==============================] - 0s 410us/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 415us/step
# 53/53 [==============================] - 0s 438us/step
# 53/53 [==============================] - 0s 409us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 410us/step
# 53/53 [==============================] - 0s 420us/step
# 53/53 [==============================] - 0s 403us/step
# 53/53 [==============================] - 0s 443us/step
# 53/53 [==============================] - 0s 469us/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 451us/step
# 53/53 [==============================] - 0s 420us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 446us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 440us/step
# 53/53 [==============================] - 0s 406us/step
# 53/53 [==============================] - 0s 417us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 426us/step
# 53/53 [==============================] - 0s 435us/step
# 53/53 [==============================] - 0s 415us/step
# 53/53 [==============================] - 0s 464us/step
# 53/53 [==============================] - 0s 452us/step
# 53/53 [==============================] - 0s 417us/step
# 53/53 [==============================] - 0s 488us/step
# 53/53 [==============================] - 0s 424us/step
# 53/53 [==============================] - 0s 425us/step
# 53/53 [==============================] - 0s 8ms/step
# 53/53 [==============================] - 0s 430us/step
# 53/53 [==============================] - 0s 418us/step
# 53/53 [==============================] - 0s 428us/step
# 53/53 [==============================] - 0s 433us/step
# 53/53 [==============================] - 0s 429us/step
# 53/53 [==============================] - 0s 421us/step
# 53/53 [==============================] - 0s 432us/step
# 53/53 [==============================] - 0s 419us/step
# 53/53 [==============================] - 0s 427us/step
# 53/53 [==============================] - 0s 422us/step
# 53/53 [==============================] - 0s 436us/step
# 53/53 [==============================] - 0s 457us/step
# 53/53 [==============================] - 0s 499us/step

# %% [markdown]
# #Conclusion
# The two goals behind the project was:
# 1. Simulate with as much fidelity as possible transmitter, receiver and decoder.
# 2. Implement the most optimized neural network decoder, and in the process develop an easily testable, customizable model for others who may be interested in this area.
#
# The first objective was successful in the scope of the project. However, additional components, such as analog to digital, digital to analog, codewords, would've more closely reflected a real communications system. However, given the limited scope, I believe the communication system reflects well on the theoretical system taught in the course.
#
# The second objective had limited success, and did not meet the criteria of which the authors of the original paper achieved. The bit error rate for 64-QAM was too high to be viable for reliable decoding. However, for BPSK, 8PSK, 4QAM and 16QAM (with additional epochs), it was found that training LLR_net at high SNR for 300 epochs allowed the LLR_net decoder to closely mimic the bit error rate of the traditional decoding system.
